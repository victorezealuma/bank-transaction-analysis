# %% [markdown]
# <a href="https://colab.research.google.com/github/victorezealuma/bank-transaction-analysis/blob/main/BankingDataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Cleaning in Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/content/drive/MyDrive/bank_transactions.csv")

df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053     10/1/94          F     JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M        JHAJJAR
# 2                  T3   C4417068    26/11/96          F         MUMBAI
# 3                  T4   C5342380     14/9/73          F         MUMBAI
# 4                  T5   C9031234     24/3/88          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229      8/4/90          M      NEW DELHI
# 1048563      T1048564   C6459278     20/2/92          M         NASHIK
# 1048564      T1048565   C6412354     18/5/89          M      HYDERABAD
# 1048565      T1048566   C6420483     30/8/78          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524      5/3/84          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df = df.rename(columns={'TransactionAmount (INR)': 'TransactionAmount(NGN)'})


df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053     10/1/94          F     JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M        JHAJJAR
# 2                  T3   C4417068    26/11/96          F         MUMBAI
# 3                  T4   C5342380     14/9/73          F         MUMBAI
# 4                  T5   C9031234     24/3/88          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229      8/4/90          M      NEW DELHI
# 1048563      T1048564   C6459278     20/2/92          M         NASHIK
# 1048564      T1048565   C6412354     18/5/89          M      HYDERABAD
# 1048565      T1048566   C6420483     30/8/78          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524      5/3/84          M           PUNE
#
#          CustAccountBalance TransactionDate  TransactionTime  \
# ...

# %%
df['TransactionTime'] = df['TransactionTime'].apply(lambda x: str(x))

df['TransactionTime'].apply(lambda x: x[0:2] + ':' + x[2:4] + ':'+ x[4:6])

df['TransactionTime'] = df['TransactionTime'].apply(lambda x: x[0:2] + ':' + x[2:4] + ':'+ x[4:6])

df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053     10/1/94          F     JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M        JHAJJAR
# 2                  T3   C4417068    26/11/96          F         MUMBAI
# 3                  T4   C5342380     14/9/73          F         MUMBAI
# 4                  T5   C9031234     24/3/88          F    NAVI MUMBAI
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229      8/4/90          M      NEW DELHI
# 1048563      T1048564   C6459278     20/2/92          M         NASHIK
# 1048564      T1048565   C6412354     18/5/89          M      HYDERABAD
# 1048565      T1048566   C6420483     30/8/78          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524      5/3/84          M           PUNE
#
#          CustAccountBalance TransactionDate TransactionTime  \
# ...

# %%
data = {'CustLocation': ['MUMBAI', 'NEW DELHI', 'BANGALORE', 'GURGAON','DELHI','PUNE','NAVI MUMBAI']}

df['CustLocation'] = df['CustLocation'].replace('MUMBAI', 'LAGOS ISLAND')
df['CustLocation'] = df['CustLocation'].replace('NEW DELHI', 'IKEJA')
df['CustLocation'] = df['CustLocation'].replace('BANGALORE', 'YABA')
df['CustLocation'] = df['CustLocation'].replace('GURGAON', 'IKORODU')
df['CustLocation'] = df['CustLocation'].replace('DELHI', 'LEKKI')
df['CustLocation'] = df['CustLocation'].replace('PUNE', 'ABULE-EGBA')
df['CustLocation'] = df['CustLocation'].replace('NAVI MUMBAI', 'MUSHIN')

df
# Out:
#         TransactionID CustomerID CustomerDOB CustGender   CustLocation  \
# 0                  T1   C5841053     10/1/94          F     JAMSHEDPUR
# 1                  T2   C2142763      4/4/57          M        JHAJJAR
# 2                  T3   C4417068    26/11/96          F   LAGOS ISLAND
# 3                  T4   C5342380     14/9/73          F   LAGOS ISLAND
# 4                  T5   C9031234     24/3/88          F         MUSHIN
# ...               ...        ...         ...        ...            ...
# 1048562      T1048563   C8020229      8/4/90          M          IKEJA
# 1048563      T1048564   C6459278     20/2/92          M         NASHIK
# 1048564      T1048565   C6412354     18/5/89          M      HYDERABAD
# 1048565      T1048566   C6420483     30/8/78          M  VISAKHAPATNAM
# 1048566      T1048567   C8337524      5/3/84          M     ABULE-EGBA
#
#          CustAccountBalance TransactionDate TransactionTime  \
# ...

# %%
specific_location = ['LAGOS ISLAND', 'IKEJA', 'YABA', 'IKORODU','LEKKI','ABULE-EGBA', 'MUSHIN']

df[df['CustLocation'].isin(specific_location)]
# Out:
#         TransactionID CustomerID CustomerDOB CustGender  CustLocation  \
# 2                  T3   C4417068    26/11/96          F  LAGOS ISLAND
# 3                  T4   C5342380     14/9/73          F  LAGOS ISLAND
# 4                  T5   C9031234     24/3/88          F        MUSHIN
# 6                  T7   C7126560     26/1/92          F  LAGOS ISLAND
# 7                  T8   C1220223     27/1/82          M  LAGOS ISLAND
# ...               ...        ...         ...        ...           ...
# 1048556      T1048557   C3414578     10/9/90          F       IKORODU
# 1048560      T1048561   C5028150     24/5/80          M    ABULE-EGBA
# 1048561      T1048562   C1034220    19/11/92          M          YABA
# 1048562      T1048563   C8020229      8/4/90          M         IKEJA
# 1048566      T1048567   C8337524      5/3/84          M    ABULE-EGBA
#
#          CustAccountBalance TransactionDate TransactionTime  \
# 2                  17874.44          2/8/16        14:27:12
# ...

# %%
df.to_csv('clean_data.csv', index=False)
