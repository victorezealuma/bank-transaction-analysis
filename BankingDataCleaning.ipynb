# %% [markdown]
# <a href="https://colab.research.google.com/github/victorezealuma/bank-transaction-analysis/blob/main/BankingDataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Data Cleaning in Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv(r"/content/drive/MyDrive/bank_transactions.csv")

df
# Out:
#        TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0                 T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1                 T2   C2142763      4/4/57          M      JHAJJAR
# 2                 T3   C4417068    26/11/96          F       MUMBAI
# 3                 T4   C5342380     14/9/73          F       MUMBAI
# 4                 T5   C9031234     24/3/88          F  NAVI MUMBAI
# ...              ...        ...         ...        ...          ...
# 295757       T295758   C1442769     13/7/75          M   AURANGABAD
# 295758       T295759   C7416886     24/7/94          M         GAYA
# 295759       T295760   C7533478    30/11/79          F         KOTA
# 295760       T295761   C7038539      8/7/90          M    BANGALORE
# 295761            T2        NaN         NaN        NaN          NaN
#
#         CustAccountBalance TransactionDate  TransactionTime  \
# 0                 17819.05          2/8/16         143207.0
# ...

# %%
df = df.drop(columns = "TransactionTime")

df
# Out:
#        TransactionID CustomerID CustomerDOB CustGender CustLocation  \
# 0                 T1   C5841053     10/1/94          F   JAMSHEDPUR
# 1                 T2   C2142763      4/4/57          M      JHAJJAR
# 2                 T3   C4417068    26/11/96          F       MUMBAI
# 3                 T4   C5342380     14/9/73          F       MUMBAI
# 4                 T5   C9031234     24/3/88          F  NAVI MUMBAI
# ...              ...        ...         ...        ...          ...
# 295757       T295758   C1442769     13/7/75          M   AURANGABAD
# 295758       T295759   C7416886     24/7/94          M         GAYA
# 295759       T295760   C7533478    30/11/79          F         KOTA
# 295760       T295761   C7038539      8/7/90          M    BANGALORE
# 295761            T2        NaN         NaN        NaN          NaN
#
#         CustAccountBalance TransactionDate  TransactionAmount (INR)
# 0                 17819.05          2/8/16                     25.0
# ...
